# %%
import pandas as pd

# %%
def tidy(df, value):
    df.Memo[df.Memo.str.contains(value)] = value

# %%
df = pd.read_csv('transactions.csv', encoding = "ISO-8859-1")
df.Memo = df.Memo.str.split(' ON', n=2, expand=True)
df.Memo = df.Memo.str.replace('&amp;', '&')
df.Memo = df.Memo.str.replace('&#039;', '')
tidy(df, 'OPEN TO LEARN')
tidy(df, 'TESCO')
tidy(df, 'IKEA')
tidy(df, 'THE GYM')
tidy(df, 'CO-OP')
tidy(df, 'TESCO')
tidy(df, 'POUNDLAND')
tidy(df, 'SHOPIFY')
tidy(df, 'ITUNES')
tidy(df, 'NATIONAL TRUST')
tidy(df, 'JOHN LEWIS')
tidy(df, 'BOOTS')
tidy(df, 'POST OFFICE')
tidy(df, 'ADOBE')
tidy(df, 'M&S')
tidy(df, 'HITACHI CAPITAL')
tidy(df, 'PRET A MANGER')
tidy(df, 'NOWTV')
tidy(df, 'HOMEBASE')
tidy(df, 'BP')
tidy(df, 'LINK')
tidy(df, 'FLUTE')
tidy(df, 'PAYROLL')
tidy(df, 'WAITROSE')
tidy(df, 'AMAZON')
tidy(df, 'Amazon')
tidy(df, 'Prime Video')
tidy(df, 'Patreon')
tidy(df, 'PUCCINOS')
tidy(df, 'MORRISONS')
tidy(df, 'SAINSBURYS')
tidy(df, 'WH SMITH')
tidy(df, 'GOOGLE')
tidy(df, 'REIGATE DANCE')
tidy(df, 'ATM')
tidy(df, 'URBAN EXPRESS')
tidy(df, 'HASTINGS INSURANCE')
tidy(df, 'OPTIONAL')
tidy(df, 'ZOPA')
tidy(df, 'VIRGIN MEDIA')
tidy(df, 'JULIA BASS')
tidy(df, 'CLAIMREF')
tidy(df, 'FAMILY EQUITY PLAN')
tidy(df, 'SANTANDER MORTGAGE')
tidy(df, 'SANTANDER UK')
tidy(df, 'DVLA')
tidy(df, 'ASD')
tidy(df, 'CARDTRONICS')
tidy(df, 'SHELL')
tidy(df,'FAMILY EQUITY PLAN')
tidy(df,'FT')
tidy(df,'TFT')
tidy(df,'BCC')
tidy(df,'BGC')
tidy(df,'ABBEY MASTERCARD')
tidy(df,'SPAR')
tidy(df,'MCDONALDS')
tidy(df,'STARBUCKS')
tidy(df, 'BARCLAYS PRTNR FIN')
tidy(df,'ITSU')
tidy(df,'O2')
tidy(df, 'COMPANIES HOUSE')
tidy(df, 'BURGER KING')
tidy(df, 'COSTA COFFEE')
tidy(df, 'COSTA')
tidy(df, 'ESSO')
tidy(df, 'FUN LEARNING')
tidy(df, 'AMZN DIGITAL')
tidy(df, 'Booking.com')
tidy(df, 'HASTINGS')
tidy(df, 'IZ *')
tidy(df, 'PAYPAL')
tidy(df, 'RBS')
tidy(df, 'NATIONWIDE')
tidy(df, 'HALIFAX')
tidy(df, 'LEON')
tidy(df, 'HSBC')
tidy(df, 'NAT WEST')
tidy(df, 'BANK OF IRELAND')
tidy(df, 'NOTEMACHINE')
tidy(df, 'LLOYDS')
tidy(df, 'WAGAMAMA')
tidy(df, 'SANTANDERCARDS')
tidy(df, 'EASYJET')
tidy(df, 'B & Q')
tidy(df, 'FACEBK')
tidy(df, 'GRABTHAI')
tidy(df, 'Kindle Svcs')
tidy(df, 'OLE STEEN')
tidy(df, 'PHARMACY')
tidy(df, 'INDIGO PARK')
tidy(df, 'KFC')
tidy(df, 'GREENWICH LEISURE')
tidy(df, 'NEW LOOK')
tidy(df, 'BUXFER')
tidy(df, 'PARKING')
tidy(df, 'SPORTSDIRECT')
tidy(df, 'HMRC')
tidy(df, 'OXFAM')
tidy(df, 'AMZN Mktp')
tidy(df, 'CAFFE NERO')
tidy(df, 'ESURE')
tidy(df, 'UBER')
tidy(df, 'HALFORDS')
tidy(df, 'COTE')
tidy(df, 'ALDI')
tidy(df, 'ZARA')
tidy(df, 'Spotify')
tidy(df, 'EVO ENERGY')
tidy(df, 'MARKS & SPENCER')    
tidy(df, 'MARKS&SPENCER')    
tidy(df, 'AMZN')
tidy(df, 'AMZ UK')
tidy(df, 'B/CARD PLAT VISA')
tidy(df, 'BARCLAYCARD')
tidy(df, 'STEAMGAMES')
tidy(df, 'DUTY FREE')
tidy(df, 'ACCESSORIZE')
tidy(df, 'ETSY')
tidy(df, 'H&M')
tidy(df, 'DIWALI INDIAN')
tidy(df, 'NEXT')
tidy(df, 'WELCOME BREAK')
tidy(df, 'TFL')
tidy(df, 'BANK MACHINE')
tidy(df, 'AUDIBLE')
tidy(df, 'Audible')
tidy(df, 'AMZ')
tidy(df, 'BENTALL')
tidy(df, 'BIG YELLOW')
tidy(df, 'BOCKETS FARM')
tidy(df, 'JEWSON')
tidy(df, 'J D SPORTS')
tidy(df, 'FAT FACE')
tidy(df, 'GAP')
tidy(df, 'RATESETTER')
tidy(df, 'DUBLIN AIRPORT')
tidy(df, 'PRIORY FARM')
tidy(df, 'ARGOS')
tidy(df, 'RYMAN')
tidy(df, 'ORANGE')
tidy(df, 'TICKETLINE')
tidy(df, 'TSB PLC')
tidy(df, 'CHESSINGTON')
tidy(df, 'SPICE GURU')
tidy(df, 'WASABI')
tidy(df, 'CLINTONS')
tidy(df, 'SCREWFIX')
tidy(df, 'APPLE')
tidy(df, 'TURKEY')
tidy(df, 'FRANCE')
tidy(df, 'TAXI')
tidy(df, 'TIMPSON')
tidy(df, 'EVERYMAN')
tidy(df, 'HOWDENS')
tidy(df, 'GATWICK')
tidy(df, 'PRIMARK')
tidy(df, 'SUPERDRUG')
tidy(df, 'MINDSHARE')
tidy(df, 'ODEON BAR')
tidy(df, 'LUSH')
tidy(df, 'MONSOON')
tidy(df, 'MOTO')
tidy(df, 'BILLS')
tidy(df, 'TRAVELEX')
tidy(df, 'MOTHERCARE')
tidy(df, 'RAPHAELS BANK')
tidy(df, 'RONTEC')
tidy(df, 'Uber')
tidy(df, 'PLAYGATE LTD')
tidy(df, 'BELGIUM')
tidy(df, 'SPAIN')
tidy(df, 'SWITZERLAND')
tidy(df, 'THE ENTERTAINER')
tidy(df, 'SPAIN')
tidy(df, 'DUBLIN T2')
tidy(df, 'AER LINGUS')
tidy(df, 'BREWDOG')
tidy(df, 'MAPLIN')
tidy(df, 'GREGGS')
tidy(df, 'CHECKMYFILE')
tidy(df, 'JUST EAT')
tidy(df, 'FEATHERDOWN')
tidy(df, 'AUSTRIA')
tidy(df, 'KINDLE')
tidy(df, 'AIRBNB')
tidy(df, 'Virgin Retail')
tidy(df, 'ALICE HOLT')
tidy(df, 'AER LINGUS')
tidy(df, 'FIVE GUYS')
tidy(df, 'MONEYCORP')
tidy(df, 'OMNICASH')
tidy(df, 'Air Hop')
tidy(df, 'D J WILKINS')
tidy(df, 'RYANAIR')
tidy(df, 'HOTEL DU VIN')
tidy(df, 'LATCHMERE SCHOOL')
tidy(df, 'WOOLWICH MORT')
tidy(df, '7IM')
tidy(df, 'NANDOS')
tidy(df, 'Account Fee')
tidy(df, 'ACCOUNT FEE')
tidy(df, 'UNPAID FEE')
tidy(df, 'STEIN DAVI')
tidy(df, 'MUELLER M')
tidy(df, 'RAPHAELS BANK')
tidy(df, 'NANDOS')
tidy(df, 'ACE OF SPADES')
tidy(df, 'PIZZA EXPRESS')
tidy(df, 'BIGYELLOWSELFSTORA')
tidy(df, 'IMF0E')
# Out:
# C:\Anaconda37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfg = df.groupby(['Memo', 'Date'])

import seaborn as sns
# %matplotlib inline
import ipywidgets as widgets

widgets.Dropdown(
    options=df.Memo.unique(),
    description='Number:',
    disabled=False,
)
df[df.Memo == 'OPEN TO LEARN'].plot(kind='barh')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = df[df.Memo.str.contains('COSTA')] 

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="Amount", y="Date", data=crashes, label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right")
ax.set(ylabel="", xlabel="Amount")
#sns.despine(left=True, bottom=True)
# Out:
# [Text(0, 0.5, ''), Text(0.5, 0, 'Amount')]

# %%
# Out:
#              Date            Account  Amount Subcategory           Memo
# 0      16/09/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 244    15/08/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 517    15/07/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 741    17/06/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 1008   15/05/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 1250   15/04/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 1529   15/03/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 1750   15/02/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 1984   15/01/2019  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 2237   17/12/2018  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 2484   15/11/2018  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# 2691   15/10/2018  20-26-46 83746836   -20.0   REPEATPMT  OPEN TO LEARN
# ...
