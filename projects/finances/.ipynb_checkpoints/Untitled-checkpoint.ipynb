# %%
import pandas as pd

# %matplotlib inline

# %%
df=pd.read_csv('2019.csv')
keywords = [' ON ', 'SAINSBURYS', 'WAGAMAMA', 'CO-OP', 'COSTA']
keywords = [' ON ', '\*', '/', 'LTD',' PO ', ' BC', ' STORES ', ' REDHILL', ' MORTGAGE ', ' CO ', ' CONNEC', ' PYMTS ', ' FINANCI    ', ' PLC ', ' CAPITAL ', ' LIMITED ', ' MEM ', ' MIA ', ' NDDS ', ' PL ']
tidy(df, keywords)
#tidy(df, [' ON ', 'SAINSBURYS', 'WAGAMAMA', 'CO-OP', 'COSTA'])
#df['MMO'] = res[0]
#df
df['Memo'] = df['Memo'].str.strip()
df.Memo.unique()
df[df.Su]
# Out:
#             Date            Account   Amount  Subcategory  \
# 0     13/09/2019  20-26-46 83746836   -18.99  DIRECTDEBIT
# 1     13/09/2019  20-26-46 83746836   -50.00           FT
# 2     12/09/2019  20-26-46 83746836    -9.30      PAYMENT
# 3     12/09/2019  20-26-46 83746836    -3.00      PAYMENT
# 4     12/09/2019  20-26-46 83746836    -8.99      PAYMENT
# 5     11/09/2019  20-26-46 83746836    -2.50      PAYMENT
# 6     11/09/2019  20-26-46 83746836   -50.00         CASH
# 7     11/09/2019  20-26-46 83746836  -100.00      PAYMENT
# 8     11/09/2019  20-26-46 83746836    -7.99      PAYMENT
# 9     10/09/2019  20-26-46 83746836    -0.90      PAYMENT
# 10    10/09/2019  20-26-46 83746836  -101.32      PAYMENT
# 11    10/09/2019  20-26-46 83746836    -7.99      PAYMENT
# 12    10/09/2019  20-26-46 83746836    -3.24      PAYMENT
# 13    10/09/2019  20-26-46 83746836    -2.30      PAYMENT
# 14    09/09/2019  20-26-46 83746836   288.45           FT
# 15    09/09/2019  20-26-46 83746836   -82.00           FT
# 16    09/09/2019  20-26-46 83746836   -10.00      PAYMENT
# 17    09/09/2019  20-26-46 83746836    -7.20      PAYMENT
# 18    09/09/2019  20-26-46 83746836    -5.35      PAYMENT
# 19    09/09/2019  20-26-46 83746836    -3.00      PAYMENT
# 20    09/09/2019  20-26-46 83746836    -2.00      PAYMENT
# 21    09/09/2019  20-26-46 83746836   -28.00      PAYMENT
# 22    09/09/2019  20-26-46 83746836   -24.29      PAYMENT
# 23    09/09/2019  20-26-46 83746836    -2.70      PAYMENT
# 24    09/09/2019  20-26-46 83746836    -0.79      PAYMENT
# 25    09/09/2019  20-26-46 83746836  -300.00         CASH
# 26    09/09/2019  20-26-46 83746836   -10.50  DIRECTDEBIT
# 27    06/09/2019  20-26-46 83746836   119.31           FT
# 28    06/09/2019  20-26-46 83746836   -65.00           FT
# 29    06/09/2019  20-26-46 83746836  -250.00      PAYMENT
# 17                                    COSTA COFFEE
# 18                               MARKS&amp;SPENCER
# 19                              EAST SURREY HOSPIT
# 20                                       POUNDLAND
# 21                                        HOMEBASE
# 22                                         SHOPIFY
# 23                                    COSTA COFFEE
# 24                                      ITUNES.COM
# 25                              202397 07SEP 14.52
# 26                                  NATIONAL TRUST
# 27     204981 63357538       SHOPIFY MAY-SEPT   FT
# 28                              REIGATE DANCE COMP
# 29                                      JOHN LEWIS
# ...                                            ...
# 2027                                 MILK&amp;MORE
# 2028                               SAINSBURYS BANK
# 2029                                          HMRC
# 2030                                  Amazon.co.uk
# 2031  309001 00042186       mam                BGC
# 2032                            WAGAMAMA ROYAL FES
# 2033                                      PUCCINOS
# 2034                            LEVY RESTAURANTS U
# 2035                            LEVY RESTAURANTS U
# 2036                                           EAT
# 2037                            NEW SOUTHERN RAILW
# 2038                                 INDIGO UK-GTR
# 2039                                        GOOGLE
# 2040  ABBEY MASTERCARD C    5286897469256575   STO
# 2041                                NATIONAL TRUST
# 2042   204676 93127729       MOBILE-CHANNEL     FT
# 2043  FIRST UTILITY         2006274            BBP
# 2044                                     SANTANDER
# 2045  GREENWICH LEISURE     AX0310034098       DDR
# 2046                                  VIRGIN MEDIA
# 2047  DVLA-YF06BSY          000000000014062300 DDR
# 2048                                  AMZN Mktp UK
# 2049                                  AMZN DIGITAL
# 2050                            TIMPSON INSIDE MOR
# 2051                                  COSTA COFFEE
# 2052                             BETWEEN THE LINES
# 2053                                  WWW.IKEA.COM
# 2054                            WM MORRISONS STORE
# 2055                                      HOMEBASE
# 2056                             BETWEEN THE LINES
#
# [2057 rows x 5 columns]

# %%
memo = df.Memo.str.split(pat=' ON ', n=1, expand=True)
df['Memo'] = memo[0]


df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df['year'] = pd.DatetimeIndex(df['Date']).year
df['month'] = pd.DatetimeIndex(df['Date']).month

df=df[['year', 'month','Memo', 'Subcategory', 'Amount']]

# %%
dfg=df.groupby(['Memo', 'Subcategory','month'], as_index=False)['Amount'].sum().sort_values('month')#.sort_values(['Amount', 'month'])
dfg = dfg[dfg.Amount < 0]
dfg = dfg[dfg.Subcategory != 'DIRECTDEBIT']
dfg.head()
# Out:
#                                              Memo Subcategory  month  Amount
# 665  MORTONS               IRELAND                    PAYMENT      1   -7.47
# 510  HSBC                  403810REIGATE                 CASH      1  -50.00
# 520                         INDIGO UK-GTR             PAYMENT      1  -28.35
# 524                         INSIDE OUT HEALTH         PAYMENT      1  -37.95
# 529  ITUNES.COM/BILL       IRELAND                    PAYMENT      1   -9.78

# %%
def tidy(df, keywords):
    
    for kw in keywords:
        res = df.Memo.str.split(pat=kw, n=1, expand=True)
        df['Memo'] = res[0]
    return df
